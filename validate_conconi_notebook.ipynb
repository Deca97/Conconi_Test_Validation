# %%
import os
import numpy as np
import pandas as pd
import pwlf
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from typing import Tuple, Optional, Dict, Any, List
from tabulate import tabulate


# ===============================
#   UTILS: resampling, smoothing, outlier removal
# ===============================

def resample_data(x: np.ndarray, y: np.ndarray, num_points: int = 200, deg: int = 3) -> Tuple[np.ndarray, np.ndarray]:
    """
    Ricampionamento usando fit polinomiale di grado `deg`.
    Restituisce x_new (velocità) e y_new (segnale ricampionati).
    """
    x = np.array(x)
    y = np.array(y)
    if len(x) < deg + 1:
        # fallback: semplice interp lineare
        x_new = np.linspace(x.min(), x.max(), num_points)
        y_new = np.interp(x_new, x, y)
        return x_new, y_new

    coeffs = np.polyfit(x, y, deg)
    poly = np.poly1d(coeffs)
    x_new = np.linspace(x.min(), x.max(), num_points)
    y_new = poly(x_new)
    return x_new, y_new

def apply_savgol(data: np.ndarray, window_length: Optional[int] = None, polyorder: int = 3) -> np.ndarray:
    """
    Applica filtro Savitzky-Golay. Sceglie una finestra valida (dispari e <= len(data)).
    Se len(data) < 5, ritorna i dati non filtrati.
    """
    n = len(data)
    if n < 5:
        return data.copy()
    if window_length is None:
        # scegliere una finestra ~ 1/15 della lunghezza, almeno 5
        wl = max(5, int(np.floor(n / 15)))
    else:
        wl = int(window_length)
    # assicurarsi sia dispari
    if wl % 2 == 0:
        wl += 1
    if wl >= n:
        wl = n - 1 if (n - 1) % 2 == 1 else n - 2
    if wl < 3:
        wl = 3
    try:
        return savgol_filter(data, window_length=wl, polyorder=polyorder)
    except Exception:
        # fallback safety
        return data.copy()

def paired_iqr_outlier_removal(x: np.ndarray, y: np.ndarray, k: float = 1.5) -> Tuple[np.ndarray, np.ndarray]:
    """
    Rimuove coppie (x,y) dove y è outlier secondo IQR.
    Restituisce x_filtered, y_filtered (allineati).
    """
    y = np.array(y)
    x = np.array(x)
    if len(y) < 4:
        return x, y
    q1 = np.percentile(y, 25)
    q3 = np.percentile(y, 75)
    iqr = q3 - q1
    low = q1 - k * iqr
    high = q3 + k * iqr
    mask = (y >= low) & (y <= high) & np.isfinite(y)
    return x[mask], y[mask]



# ===============================
#   CALCOLO SOGLIA (generico per un segnale vs speed)
# ===============================

def calculate_threshold_piecewise(signal: np.ndarray,
                                  speed: np.ndarray,
                                  num_points: int = 100,        # sempre 100
                                  poly_deg: int = 3,
                                  savgol_wl: Optional[int] = None,
                                  savgol_order: int = 3,
                                  skip_initial: int = 40,       
                                  iqr_k: float = 1.5,
                                  slope_change_required: Optional[float] = None,
                                  slope_direction: Optional[str] = None   # 'increase' o 'decrease'
                                  ) -> Tuple[Optional[float], Optional[float], Optional[int], Optional[Tuple[np.ndarray, np.ndarray, np.ndarray]], Optional[str]]:
    """
    Pipeline:
      - resample sempre a 100 punti
      - scarta sempre i primi N punti
      - savgol smoothing
      - paired outlier removal (IQR)
      - fit piecewise lineare
      - controllo pendenza se richiesto: aumento o diminuzione
    """
    try:
        sp_res, sig_res = resample_data(speed, signal, num_points=num_points, deg=poly_deg)
    except Exception as e:
        return None, None, None, None, f"Errore ricampionamento: {e}"

    # scarta i primi punti
    if len(sp_res) > skip_initial:
        sp_res = sp_res[skip_initial:]
        sig_res = sig_res[skip_initial:]

    # smoothing Savitzky-Golay
    sig_smooth = apply_savgol(sig_res, window_length=savgol_wl, polyorder=savgol_order)
    # paired outlier removal
    sp_filt, sig_filt = paired_iqr_outlier_removal(sp_res, sig_smooth, k=iqr_k)

    if len(sp_filt) < 8:
        return None, None, None, None, "Dati insufficienti dopo filtraggio/outlier removal"

    # Fit piecewise lineare
    try:
        pwlf_model = pwlf.PiecewiseLinFit(sp_filt, sig_filt)
        breaks = pwlf_model.fit(2)  # 2 segmenti → 1 breakpoint
        sig_fit = pwlf_model.predict(sp_filt)
        slopes = pwlf_model.calc_slopes()  # [slope1, slope2]
    except Exception as e:
        return None, None, None, None, f"Errore fit PWLF: {e}"

    # Controllo pendenza
    if slope_change_required is not None and slope_direction is not None:
        if len(slopes) < 2:
            return None, None, None, None, "Impossibile calcolare pendenze"
        if slope_direction == 'increase':
            # LACT: slope2 deve aumentare almeno del x% rispetto a slope1
            if slopes[1] < slopes[0] * (1.0 + slope_change_required):
                return None, None, None, None, f"Slope non aumenta di almeno {slope_change_required*100:.0f}% dopo breakpoint"
        elif slope_direction == 'decrease':
            # HR: slope2 deve diminuire almeno del x% rispetto a slope1, ma restare positiva
            if slopes[1] > slopes[0] * (1.0 - slope_change_required) or slopes[1] <= 0:
                return None, None, None, None, f"Slope non diminuisce di almeno {slope_change_required*100:.0f}% dopo breakpoint o diventa <=0"
        else:
            return None, None, None, None, "slope_direction deve essere 'increase' o 'decrease'"

    # threshold speed e segnale
    threshold_speed = breaks[1]
    try:
        threshold_signal = pwlf_model.predict([threshold_speed])[0]
    except Exception:
        threshold_signal = None

    idx = int(np.argmin(np.abs(sp_filt - threshold_speed)))

    return threshold_signal, threshold_speed, idx, (sp_filt, sig_filt, sig_fit), None

def speed_to_pace(speed_kmh):
    """Converte km/h in stringa mm:ss/km"""
    if speed_kmh is None or speed_kmh <= 0:
        return "N/A"
    total_min = 60 / speed_kmh
    minutes = int(total_min)
    seconds = int(round((total_min - minutes) * 60))
    return f"{minutes}:{seconds:02d} min/km"


# ===============================
#   MAIN: validate_conconi 
# ===============================

def validate_conconi(summary_file: str,
                     base_path: str,
                     save_plots: bool = True,
                     plots_folder_name: str = "plots"):
    os.makedirs(os.path.join(base_path, plots_folder_name), exist_ok=True)
    df_summary = pd.read_excel(summary_file)
    results = []

    for _, row in df_summary.iterrows():
        if 'sport' in row and str(row['sport']).lower() != 'running':
            continue

        athlete_file = os.path.join(base_path, row['file'])
        print(f"\nProcessing {athlete_file}")

        try:
            df_data = pd.read_excel(athlete_file, sheet_name="Sheet2")
        except Exception as e:
            print(f"Errore file {athlete_file}: {e}")
            continue

        available_cols = list(df_data.columns)
        speed_col_candidates = ['Actual Power', 'Speed', 'Velocità', 'Velocity', 'speed']
        hr_col_candidates = ['HR', 'HeartRate', 'heart_rate', 'hr']
        lact_col_candidates = ['Bla', 'Lactate', 'Lact', 'bLa', 'bla']

        def pick_col(cands, cols):
            for c in cands:
                if c in cols:
                    return c
            return None

        speed_col = pick_col(speed_col_candidates, available_cols)
        hr_col = pick_col(hr_col_candidates, available_cols)
        lact_col = pick_col(lact_col_candidates, available_cols)

        if speed_col is None or hr_col is None or lact_col is None:
            print(f"[WARN] Colonne mancanti in {athlete_file}. Trovate: {available_cols}")
            continue

        sp = pd.to_numeric(df_data[speed_col], errors='coerce').dropna().values
        hr = pd.to_numeric(df_data[hr_col], errors='coerce').dropna().values
        lact = pd.to_numeric(df_data[lact_col], errors='coerce').dropna().values

        if len(sp) < 6 or len(hr) < 6 or len(lact) < 6:
            print(f"[WARN] Dati troppo pochi in {athlete_file}. sp:{len(sp)}, hr:{len(hr)}, lact:{len(lact)}")
            continue

        # HR-based PWLF
        est_hr_val, est_sp_hr, idx_hr, debug_hr, warn_hr = calculate_threshold_piecewise(
            signal=hr, speed=sp, num_points=100, poly_deg=3, skip_initial=40,
            slope_change_required=0.10, slope_direction='decrease'
        )

        # LATTATO curve & automatic estimate (solo per fit/curve)
        est_lact_val_auto, est_sp_lact_auto, idx_lact_auto, debug_lact, warn_lact = calculate_threshold_piecewise(
            signal=lact, speed=sp, num_points=100, poly_deg=3, skip_initial=40,
            slope_change_required=0.30, slope_direction='increase'
        )

        # --- Lettura Sheet3 (Load @ Tlac, HR @ Tlac, BLA @ Tlac se presente) ---
        est_sp_lact_sheet = None      # Load @ Tlac (velocità)
        hr_at_tlac_sheet = None       # HR @ Tlac (bpm)
        bla_at_tlac_sheet = None      # Bla @ Tlac (mmol/L) -- nuovo campo

        try:
            df_sheet3 = pd.read_excel(athlete_file, sheet_name="Sheet3", header=None)
            sheet3_dict = dict(zip(df_sheet3.iloc[:, 0].astype(str).str.strip(), df_sheet3.iloc[:, 1]))
            # recupero con chiavi esatte
            load_tlac = sheet3_dict.get("Load @ Tlac", None)
            hr_tlac = sheet3_dict.get("HR @ Tlac", None)
            bla_tlac = sheet3_dict.get("Bla @ Tlac", sheet3_dict.get("Bla @ Tlac".strip(), None))
            # converti quando possibile
            try:
                est_sp_lact_sheet = float(load_tlac) if pd.notnull(load_tlac) else None
            except Exception:
                est_sp_lact_sheet = None
            try:
                hr_at_tlac_sheet = float(hr_tlac) if pd.notnull(hr_tlac) else None
            except Exception:
                hr_at_tlac_sheet = None
            try:
                bla_at_tlac_sheet = float(bla_tlac) if pd.notnull(bla_tlac) else None
            except Exception:
                bla_at_tlac_sheet = None
        except Exception as e:
            print(f"[WARN] Nessuna Sheet3 o errore lettura in {athlete_file}: {e}")

        # Usare est_sp_lact_sheet come soglia lact (velocità) se presente, altrimenti None
        est_sp_lact = est_sp_lact_sheet if est_sp_lact_sheet is not None else None
        # Per il valore di lattato da plottare: preferiamo Bla @ Tlac da Sheet3; fallback = valore stimato automaticamente dal fit (est_lact_val_auto)
        est_lact_val = None
        if bla_at_tlac_sheet is not None:
            est_lact_val = bla_at_tlac_sheet
        elif est_lact_val_auto is not None:
            est_lact_val = est_lact_val_auto
        else:
            est_lact_val = None

        # Calcolo HR interpolato alla velocità di soglia lattato (se possibile)
        hr_at_lact_speed = None
        hr_at_hr_speed = None
        if debug_hr is not None and est_sp_lact is not None:
            sp_hr_filt, hr_filt, hr_fit_line = debug_hr
            try:
                pw = pwlf.PiecewiseLinFit(sp_hr_filt, hr_filt)
                pw.fit(2)
                hr_at_lact_speed = float(pw.predict([est_sp_lact])[0])
                hr_at_hr_speed = float(pw.predict([est_sp_hr])[0]) if est_sp_hr is not None else None
            except Exception:
                try:
                    hr_at_lact_speed = np.interp(est_sp_lact, sp_hr_filt, hr_fit_line)
                    hr_at_hr_speed = np.interp(est_sp_hr, sp_hr_filt, hr_fit_line) if est_sp_hr is not None else None
                except Exception:
                    hr_at_lact_speed, hr_at_hr_speed = None, None

        # Confronti (restano invariati)
        err_speed = None
        err_hr = None
        if (est_sp_hr is not None) and (est_sp_lact is not None):
            err_speed = est_sp_hr - est_sp_lact
            if (est_hr_val is not None) and (hr_at_lact_speed is not None):
                err_hr = est_hr_val - hr_at_lact_speed
            elif (hr_at_hr_speed is not None) and (hr_at_lact_speed is not None):
                err_hr = hr_at_hr_speed - hr_at_lact_speed

        print(f"\nStimato HR-based: {est_sp_hr} km/h ({speed_to_pace(est_sp_hr)}), val segnale: {est_hr_val}")
        print(f"Letto LACT-based (Sheet3 Load @ Tlac): {est_sp_lact}, Bla@Tlac (sheet3): {bla_at_tlac_sheet}, HR@Tlac (sheet3): {hr_at_tlac_sheet}")

        # metriche e raccolta risultati (come prima)
        def speed_to_pace_sec(speed_kmh):
            if speed_kmh is None or speed_kmh <= 0:
                return np.nan
            return 3600 / speed_kmh

        pace_err_sec = None
        if (est_sp_hr is not None) and (est_sp_lact is not None):
            pace_err_sec = speed_to_pace_sec(est_sp_hr) - speed_to_pace_sec(est_sp_lact)

        results.append({
            "athlete_file": row['file'],
            "est_sp_hr": est_sp_hr,
            "est_hr_val": est_hr_val,
            "est_sp_lact": est_sp_lact,
            "est_lact_val": est_lact_val,
            "hr_at_lact_speed": hr_at_lact_speed,
            "err_sp_hr_minus_lact": err_speed,
            "err_hr_between_methods": err_hr,
            "err_pace_sec_per_km": pace_err_sec,
            "warn_hr": warn_hr,
            "warn_lact": warn_lact
        })

        # === Plot combinato e salvataggio ===
        if save_plots and debug_hr is not None and debug_lact is not None:
            try:
                plt.figure(figsize=(8, 5))
                ax1 = plt.gca()

                # --- HR-based (asse sinistro) ---
                sp_hr_plot, hr_plot, hr_fit_plot = debug_hr
                ax1.scatter(sp_hr_plot, hr_plot, marker='o', color='tab:red', label='HR misurata', alpha=0.6)
                ax1.plot(sp_hr_plot, hr_fit_plot, linestyle='-', linewidth=2, color='red', label='Fit HR (PWLF)')
                if est_sp_hr is not None and est_hr_val is not None:
                    ax1.scatter(est_sp_hr, est_hr_val, marker='X', s=100,
                                label='Soglia HR-based', color='darkred', zorder=6)

                ax1.set_xlabel("Velocità (km/h)")
                ax1.set_ylabel("Frequenza cardiaca (bpm)", color='tab:red')
                ax1.tick_params(axis='y', colors='tab:red')

                # --- Lattato-based (asse destro) ---
                ax2 = ax1.twinx()
                sp_l_plot, lact_plot, lact_fit_plot = debug_lact
                ax2.scatter(sp_l_plot, lact_plot, marker='s', color='tab:blue', label='Lattato misurato', alpha=0.6)
                ax2.plot(sp_l_plot, lact_fit_plot, linestyle='--', linewidth=2,
                         color='blue', label='Fit Lattato (PWLF)')

                # punto soglia lattato
                if est_sp_lact is not None and est_lact_val is not None:
                    ax2.scatter(est_sp_lact, est_lact_val, marker='D', s=100,
                                label='Soglia Lattato-based', color='navy', zorder=7)

                ax2.set_ylabel("Lattato (mmol/L)", color='tab:blue')
                ax2.tick_params(axis='y', colors='tab:blue')

                # --- HR interpolato alla velocità di soglia lattato (mostra solo se HR-based e Lattato-based sono separati) ---
                if hr_at_lact_speed is not None and est_sp_lact is not None:
                    ax1.scatter(est_sp_lact, hr_at_lact_speed, marker='^', s=80,
                                label='HR alla soglia lattato', color='orange', zorder=7)

                # --- legende e layout ---
                handles1, labels1 = ax1.get_legend_handles_labels()
                handles2, labels2 = ax2.get_legend_handles_labels()
                ax1.legend(handles1 + handles2, labels1 + labels2, loc='best')

                plt.title(f"Soglie HR e Lattato — {row['file']}")
                plt.grid(True)
                plt.tight_layout()

                # salvataggio
                athlete_name = os.path.splitext(os.path.basename(row['file']))[0]
                plot_path = os.path.join(base_path, plots_folder_name, f"soglie_{athlete_name}.png")
                plt.savefig(plot_path, dpi=300)
                print(f"Plot salvato: {plot_path}")

                # plt.show()
                plt.close()

            except Exception as e:
                print(f"[WARN] Errore nel plotting di {athlete_file}: {e}")


    # --- metrics aggregation (invariata) ---
    df_results = pd.DataFrame(results)
    for c in ['est_sp_hr','est_sp_lact','est_hr_val','est_lact_val','hr_at_lact_speed','err_sp_hr_minus_lact','err_hr_between_methods', 'err_pace_sec_per_km']:
        if c in df_results.columns:
            df_results[c] = pd.to_numeric(df_results[c], errors='coerce')

    def safe_mae(s): s=s.dropna(); return np.mean(np.abs(s)) if len(s) else np.nan
    def safe_mdae(s): s=s.dropna(); return np.median(np.abs(s)) if len(s) else np.nan
    def safe_me(s): s=s.dropna(); return np.mean(s) if len(s) else np.nan
    def safe_mde(s): s=s.dropna(); return np.median(s) if len(s) else np.nan

    metrics = {
        "N_tests": int(df_results.dropna(subset=['est_sp_hr','est_sp_lact']).shape[0]),
        "MAE_speed_between_methods_kmh": safe_mae(df_results['err_sp_hr_minus_lact']),
        "MDAE_speed_between_methods_kmh": safe_mdae(df_results['err_sp_hr_minus_lact']),
        "ME_speed_between_methods_kmh": safe_me(df_results['err_sp_hr_minus_lact']),
        "MDE_speed_between_methods_kmh": safe_mde(df_results['err_sp_hr_minus_lact']),
        "MAE_hr_between_methods_bpm": safe_mae(df_results['err_hr_between_methods']),
        "MDAE_hr_between_methods_bpm": safe_mdae(df_results['err_hr_between_methods']),
        "ME_hr_between_methods_bpm": safe_me(df_results['err_hr_between_methods']),
        "MDE_hr_between_methods_bpm": safe_mde(df_results['err_hr_between_methods']),
        "MAE_pace_between_methods_sec_per_km": safe_mae(df_results['err_pace_sec_per_km']),
        "MDAE_pace_between_methods_sec_per_km": safe_mdae(df_results['err_pace_sec_per_km']),
        "ME_pace_between_methods_sec_per_km": safe_me(df_results['err_pace_sec_per_km']),
        "MDE_pace_between_methods_sec_per_km": safe_mde(df_results['err_pace_sec_per_km']),
    }

    return df_results, metrics





summary_file = r"C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\Data_Summary.xlsx"
base_path = r"C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data"
results_df, metrics = validate_conconi(summary_file, base_path, save_plots=True)
# Out:
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1042.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 20.4, Bla@Tlac (sheet3): 2.1, HR@Tlac (sheet3): 173.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1041.xlsx
#
# Stimato HR-based: 16.059484891044896 km/h (3:44 min/km), val segnale: 163.8766327946526
# Letto LACT-based (Sheet3 Load @ Tlac): 16.6, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 166.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1041.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A104.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.1, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 176.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1038.xlsx
#
# Stimato HR-based: 16.867011830452714 km/h (3:33 min/km), val segnale: 154.72938511325026
# Letto LACT-based (Sheet3 Load @ Tlac): 19.3, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 170.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1038.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1039.xlsx
#
# Stimato HR-based: 17.05002891255227 km/h (3:31 min/km), val segnale: 159.588252386509
# Letto LACT-based (Sheet3 Load @ Tlac): 17.8, Bla@Tlac (sheet3): 3.5, HR@Tlac (sheet3): 165.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1039.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1040.xlsx
#
# Stimato HR-based: 15.577007306772593 km/h (3:51 min/km), val segnale: 166.75811718293988
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 170.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1040.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1034.xlsx
#
# Stimato HR-based: 14.161198299236556 km/h (4:14 min/km), val segnale: 151.31106019452892
# Letto LACT-based (Sheet3 Load @ Tlac): 14.9, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 155.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1034.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1035.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 20.1, Bla@Tlac (sheet3): 3.9, HR@Tlac (sheet3): 172.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1037.xlsx
#
# Stimato HR-based: 12.777144145848776 km/h (4:42 min/km), val segnale: 164.7002354272684
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 1.5, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1037.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1036.xlsx
#
# Stimato HR-based: 17.92092545880679 km/h (3:21 min/km), val segnale: 186.2058874498817
# Letto LACT-based (Sheet3 Load @ Tlac): 18.1, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 188.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1036.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1032.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 183.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1029.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 15.9, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 172.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1031.xlsx
#
# Stimato HR-based: 14.99273526221501 km/h (4:00 min/km), val segnale: 161.45251759614536
# Letto LACT-based (Sheet3 Load @ Tlac): 15.6, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 165.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1031.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1030.xlsx
#
# Stimato HR-based: 12.70755376943035 km/h (4:43 min/km), val segnale: 188.39217326268576
# Letto LACT-based (Sheet3 Load @ Tlac): 13.9, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 195.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1030.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A103.xlsx
#
# Stimato HR-based: 12.358376971044665 km/h (4:51 min/km), val segnale: 177.921608503941
# Letto LACT-based (Sheet3 Load @ Tlac): 14.2, Bla@Tlac (sheet3): 4.0, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A103.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1033.xlsx
#
# Stimato HR-based: 14.293370091160153 km/h (4:12 min/km), val segnale: 175.91237592974392
# Letto LACT-based (Sheet3 Load @ Tlac): 16.0, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1033.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1025.xlsx
#
# Stimato HR-based: 10.98319018303133 km/h (5:28 min/km), val segnale: 176.48402275628894
# Letto LACT-based (Sheet3 Load @ Tlac): 12.7, Bla@Tlac (sheet3): 3.7, HR@Tlac (sheet3): 183.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1025.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1027.xlsx
#
# Stimato HR-based: 16.23102652762206 km/h (3:42 min/km), val segnale: 174.7968220832006
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 175.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1027.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1026.xlsx
#
# Stimato HR-based: 15.572678526348371 km/h (3:51 min/km), val segnale: 158.20298899798104
# Letto LACT-based (Sheet3 Load @ Tlac): 16.2, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 162.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1026.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1028.xlsx
#
# Stimato HR-based: 15.086947554670564 km/h (3:59 min/km), val segnale: 168.5020986777831
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 3.7, HR@Tlac (sheet3): 173.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1028.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1023.xlsx
#
# Stimato HR-based: 17.309680659681376 km/h (3:28 min/km), val segnale: 157.02695228461096
# Letto LACT-based (Sheet3 Load @ Tlac): 17.8, Bla@Tlac (sheet3): 2.5, HR@Tlac (sheet3): 161.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1023.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1021.xlsx
#
# Stimato HR-based: 15.87200816653786 km/h (3:47 min/km), val segnale: 187.9345322437259
# Letto LACT-based (Sheet3 Load @ Tlac): 17.1, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 196.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1021.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1022.xlsx
#
# Stimato HR-based: 15.668570095428407 km/h (3:50 min/km), val segnale: 171.4797477558079
# Letto LACT-based (Sheet3 Load @ Tlac): 17.4, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 176.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1022.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A102.xlsx
#
# Stimato HR-based: 15.680630931614186 km/h (3:50 min/km), val segnale: 174.7763196377778
# Letto LACT-based (Sheet3 Load @ Tlac): 15.5, Bla@Tlac (sheet3): 2.5, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A102.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1020.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.4, Bla@Tlac (sheet3): 2.5, HR@Tlac (sheet3): 170.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1024.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 150.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1017.xlsx
#
# Stimato HR-based: 16.088204036611643 km/h (3:44 min/km), val segnale: 172.58371844855725
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 3.2, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1017.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1018.xlsx
#
# Stimato HR-based: 14.29895923227329 km/h (4:12 min/km), val segnale: 160.90072986839988
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 2.1, HR@Tlac (sheet3): 170.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1018.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1016.xlsx
#
# Stimato HR-based: 13.825023825598135 km/h (4:20 min/km), val segnale: 163.79991527294808
# Letto LACT-based (Sheet3 Load @ Tlac): 15.5, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 172.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1016.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1019.xlsx
#
# Stimato HR-based: 15.485449571366763 km/h (3:52 min/km), val segnale: 172.93162262626365
# Letto LACT-based (Sheet3 Load @ Tlac): 17.8, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1019.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1014.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.2, Bla@Tlac (sheet3): 1.9, HR@Tlac (sheet3): 171.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1010.xlsx
#
# Stimato HR-based: 15.680400428241946 km/h (3:50 min/km), val segnale: 170.92903295538565
# Letto LACT-based (Sheet3 Load @ Tlac): 16.5, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 177.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1010.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1013.xlsx
#
# Stimato HR-based: 14.295382966386308 km/h (4:12 min/km), val segnale: 166.9803091681647
# Letto LACT-based (Sheet3 Load @ Tlac): 15.9, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 176.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1013.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1012.xlsx
#
# Stimato HR-based: 15.796291505388192 km/h (3:48 min/km), val segnale: 185.6130636120125
# Letto LACT-based (Sheet3 Load @ Tlac): 16.7, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 192.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1012.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1011.xlsx
#
# Stimato HR-based: 15.102859491171523 km/h (3:58 min/km), val segnale: 153.08559393084946
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 158.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1011.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1015.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.2, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 182.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1009.xlsx
#
# Stimato HR-based: 12.833721901627031 km/h (4:41 min/km), val segnale: 160.60779322544994
# Letto LACT-based (Sheet3 Load @ Tlac): 13.3, Bla@Tlac (sheet3): 3.5, HR@Tlac (sheet3): 164.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1009.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1007.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 187.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1008.xlsx
#
# Stimato HR-based: 13.691965675224221 km/h (4:23 min/km), val segnale: 177.2743022292501
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 183.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1008.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A101.xlsx
#
# Stimato HR-based: 16.445059088283642 km/h (3:39 min/km), val segnale: 184.15294842080698
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 4.0, HR@Tlac (sheet3): 190.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A101.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1005.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.7, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 157.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1003.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.0, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 180.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1001.xlsx
#
# Stimato HR-based: 15.195295610770412 km/h (3:57 min/km), val segnale: 171.81699063609096
# Letto LACT-based (Sheet3 Load @ Tlac): 15.5, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 173.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1001.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1002.xlsx
#
# Stimato HR-based: 12.209264294888126 km/h (4:55 min/km), val segnale: 177.1353138418403
# Letto LACT-based (Sheet3 Load @ Tlac): 13.2, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1002.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1004.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 17.7, Bla@Tlac (sheet3): 1.6, HR@Tlac (sheet3): 182.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1006.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 14.6, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 161.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A100.xlsx
#
# Stimato HR-based: 16.228720027558694 km/h (3:42 min/km), val segnale: 173.09840922428523
# Letto LACT-based (Sheet3 Load @ Tlac): 18.25, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A100.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1000.xlsx
#
# Stimato HR-based: 16.684986431369367 km/h (3:36 min/km), val segnale: 186.62320494334384
# Letto LACT-based (Sheet3 Load @ Tlac): 17.5, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 191.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1000.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A111.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.5, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 186.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A110.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 15.4, Bla@Tlac (sheet3): 1.6, HR@Tlac (sheet3): 162.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A109.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 13.0, Bla@Tlac (sheet3): 2.9, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A108.xlsx
#
# Stimato HR-based: 16.784072968612854 km/h (3:34 min/km), val segnale: 169.75674763396609
# Letto LACT-based (Sheet3 Load @ Tlac): 16.6, Bla@Tlac (sheet3): 2.5, HR@Tlac (sheet3): 168.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A108.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1073.xlsx
#
# Stimato HR-based: 14.961302264434439 km/h (4:01 min/km), val segnale: 167.67311712077338
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 176.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1073.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1070.xlsx
#
# Stimato HR-based: 14.882314175713297 km/h (4:02 min/km), val segnale: 162.66768951576873
# Letto LACT-based (Sheet3 Load @ Tlac): 16.5, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 170.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1070.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1071.xlsx
#
# Stimato HR-based: 13.50277962845714 km/h (4:27 min/km), val segnale: 186.48749503163174
# Letto LACT-based (Sheet3 Load @ Tlac): 14.8, Bla@Tlac (sheet3): 2.1, HR@Tlac (sheet3): 193.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1071.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1072.xlsx
#
# Stimato HR-based: 14.970935869246922 km/h (4:00 min/km), val segnale: 178.11053418392993
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 3.1, HR@Tlac (sheet3): 188.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1072.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1066.xlsx
#
# Stimato HR-based: 13.805073440766192 km/h (4:21 min/km), val segnale: 166.04106914669632
# Letto LACT-based (Sheet3 Load @ Tlac): 14.9, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 170.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1066.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1068.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 17.2, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 162.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1065.xlsx
#
# Stimato HR-based: 13.965415134926317 km/h (4:18 min/km), val segnale: 169.81373482426648
# Letto LACT-based (Sheet3 Load @ Tlac): 15.3, Bla@Tlac (sheet3): 1.9, HR@Tlac (sheet3): 177.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1065.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1061.xlsx
#
# Stimato HR-based: 14.30713894924229 km/h (4:12 min/km), val segnale: 177.53563937713614
# Letto LACT-based (Sheet3 Load @ Tlac): 15.9, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1061.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1064.xlsx
#
# Stimato HR-based: 17.266200403396066 km/h (3:28 min/km), val segnale: 173.05497764182758
# Letto LACT-based (Sheet3 Load @ Tlac): 18.6, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 180.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1064.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1062.xlsx
#
# Stimato HR-based: 15.060745433262921 km/h (3:59 min/km), val segnale: 174.84334544172572
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 178.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1062.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A107.xlsx
#
# Stimato HR-based: 13.330781731139563 km/h (4:30 min/km), val segnale: 174.3917171555241
# Letto LACT-based (Sheet3 Load @ Tlac): 15.2, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A107.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1069.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.3, Bla@Tlac (sheet3): 4.3, HR@Tlac (sheet3): 176.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1067.xlsx
#
# Stimato HR-based: 14.856804581790874 km/h (4:02 min/km), val segnale: 170.39877558499057
# Letto LACT-based (Sheet3 Load @ Tlac): 16.4, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1067.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1063.xlsx
#
# Stimato HR-based: 12.81800745557507 km/h (4:41 min/km), val segnale: 176.84882166423114
# Letto LACT-based (Sheet3 Load @ Tlac): 13.5, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 179.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1063.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1056.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.8, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1057.xlsx
#
# Stimato HR-based: 12.982605499772909 km/h (4:37 min/km), val segnale: 175.29338613004035
# Letto LACT-based (Sheet3 Load @ Tlac): 13.45, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 177.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1057.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1058.xlsx
#
# Stimato HR-based: 13.348616875033688 km/h (4:30 min/km), val segnale: 152.7013192371166
# Letto LACT-based (Sheet3 Load @ Tlac): 17.2, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 169.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1058.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1059.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 14.3, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 168.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1052.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 12.5, Bla@Tlac (sheet3): 1.9, HR@Tlac (sheet3): 171.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1053.xlsx
#
# Stimato HR-based: 13.478417417104147 km/h (4:27 min/km), val segnale: 184.06322649296504
# Letto LACT-based (Sheet3 Load @ Tlac): 14.9, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1053.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1054.xlsx
#
# Stimato HR-based: 13.323899164792337 km/h (4:30 min/km), val segnale: 176.0255202415627
# Letto LACT-based (Sheet3 Load @ Tlac): 14.3, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 181.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1054.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1060.xlsx
#
# Stimato HR-based: 14.812171306849036 km/h (4:03 min/km), val segnale: 169.13970685985458
# Letto LACT-based (Sheet3 Load @ Tlac): 16.2, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 175.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1060.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A106.xlsx
#
# Stimato HR-based: 15.023518445779004 km/h (3:60 min/km), val segnale: 181.10424508032196
# Letto LACT-based (Sheet3 Load @ Tlac): 15.3, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A106.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1055.xlsx
#
# Stimato HR-based: 14.316988126124235 km/h (4:11 min/km), val segnale: 167.26900343554394
# Letto LACT-based (Sheet3 Load @ Tlac): 15.3, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 175.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1055.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1050.xlsx
#
# Stimato HR-based: 18.95928443049144 km/h (3:10 min/km), val segnale: 153.16451071733604
# Letto LACT-based (Sheet3 Load @ Tlac): 21.0, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 163.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1050.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1048.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 17.1, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 171.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1047.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 172.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A105.xlsx
#
# Stimato HR-based: 15.022022135864649 km/h (3:60 min/km), val segnale: 174.358070691789
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A105.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1049.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.1, Bla@Tlac (sheet3): 2.5, HR@Tlac (sheet3): 181.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1051.xlsx
#
# Stimato HR-based: 17.676594880445613 km/h (3:24 min/km), val segnale: 175.64675330826555
# Letto LACT-based (Sheet3 Load @ Tlac): 18.0, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 180.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1051.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1043.xlsx
#
# Stimato HR-based: 13.465666893504475 km/h (4:27 min/km), val segnale: 180.992488288103
# Letto LACT-based (Sheet3 Load @ Tlac): 15.3, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1043.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1044.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 14.9, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 170.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1045.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.6, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 180.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A1046.xlsx
#
# Stimato HR-based: 16.037494803227748 km/h (3:44 min/km), val segnale: 183.3486446442569
# Letto LACT-based (Sheet3 Load @ Tlac): 17.1, Bla@Tlac (sheet3): 4.0, HR@Tlac (sheet3): 190.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A1046.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A117.xlsx
#
# Stimato HR-based: 18.82884503120407 km/h (3:11 min/km), val segnale: 174.02185675996049
# Letto LACT-based (Sheet3 Load @ Tlac): 20.5, Bla@Tlac (sheet3): 3.5, HR@Tlac (sheet3): 181.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A117.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A116.xlsx
#
# Stimato HR-based: 14.90795901820209 km/h (4:01 min/km), val segnale: 190.99655459164597
# Letto LACT-based (Sheet3 Load @ Tlac): 17.3, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 202.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A116.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A115.xlsx
#
# Stimato HR-based: 14.803123157352067 km/h (4:03 min/km), val segnale: 188.4569006846677
# Letto LACT-based (Sheet3 Load @ Tlac): 15.8, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 194.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A115.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A114.xlsx
#
# Stimato HR-based: 14.673841029281936 km/h (4:05 min/km), val segnale: 186.1576707692767
# Letto LACT-based (Sheet3 Load @ Tlac): 15.7, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 190.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A114.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A113.xlsx
#
# Stimato HR-based: 16.681273843661163 km/h (3:36 min/km), val segnale: 178.53322229888994
# Letto LACT-based (Sheet3 Load @ Tlac): 19.2, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 192.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A113.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A112.xlsx
#
# Stimato HR-based: 17.72521225766286 km/h (3:23 min/km), val segnale: 181.76003076321604
# Letto LACT-based (Sheet3 Load @ Tlac): 19.5, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 192.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A112.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A123.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 17.7, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 176.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A122.xlsx
#
# Stimato HR-based: 18.61396587343257 km/h (3:13 min/km), val segnale: 181.67923604104976
# Letto LACT-based (Sheet3 Load @ Tlac): 19.1, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 185.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A122.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A121.xlsx
#
# Stimato HR-based: 17.074332825307206 km/h (3:31 min/km), val segnale: 176.94869070796028
# Letto LACT-based (Sheet3 Load @ Tlac): 19.1, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A121.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A120.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 3.3, HR@Tlac (sheet3): 170.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A119.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.3, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 183.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A118.xlsx
#
# Stimato HR-based: 18.25541248599799 km/h (3:17 min/km), val segnale: 163.71586325914333
# Letto LACT-based (Sheet3 Load @ Tlac): 20.6, Bla@Tlac (sheet3): 3.4, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A118.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A169.xlsx
#
# Stimato HR-based: 16.766058232438688 km/h (3:35 min/km), val segnale: 167.36947624773234
# Letto LACT-based (Sheet3 Load @ Tlac): 18.5, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 177.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A169.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A168.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.2, Bla@Tlac (sheet3): 3.2, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A166.xlsx
#
# Stimato HR-based: 16.82462281306231 km/h (3:34 min/km), val segnale: 174.48310104383864
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 3.1, HR@Tlac (sheet3): 180.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A166.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A167.xlsx
#
# Stimato HR-based: 16.084539657585996 km/h (3:44 min/km), val segnale: 167.9014240509184
# Letto LACT-based (Sheet3 Load @ Tlac): 18.2, Bla@Tlac (sheet3): 3.1, HR@Tlac (sheet3): 178.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A167.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A164.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 17.6, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A165.xlsx
#
# Stimato HR-based: 17.004783305929728 km/h (3:32 min/km), val segnale: 164.91028199997464
# Letto LACT-based (Sheet3 Load @ Tlac): 18.25, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 172.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A165.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A161.xlsx
#
# Stimato HR-based: 14.131533835466985 km/h (4:15 min/km), val segnale: 163.98988948048623
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 168.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A161.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A162.xlsx
#
# Stimato HR-based: 13.312286713831107 km/h (4:30 min/km), val segnale: 171.1151003105617
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 178.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A162.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A160.xlsx
#
# Stimato HR-based: 14.194466108541818 km/h (4:14 min/km), val segnale: 170.62322334431457
# Letto LACT-based (Sheet3 Load @ Tlac): 14.8, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A160.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A163.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.2, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 170.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A158.xlsx
#
# Stimato HR-based: 14.015875978286298 km/h (4:17 min/km), val segnale: 166.3535038291613
# Letto LACT-based (Sheet3 Load @ Tlac): 15.4, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A158.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A155.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.9, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A156.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.5, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 170.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A159.xlsx
#
# Stimato HR-based: 14.607386853741142 km/h (4:06 min/km), val segnale: 166.45280155367828
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 166.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A159.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A157.xlsx
#
# Stimato HR-based: 20.051045323520228 km/h (2:60 min/km), val segnale: 174.11258683405094
# Letto LACT-based (Sheet3 Load @ Tlac): 19.1, Bla@Tlac (sheet3): 1.6, HR@Tlac (sheet3): 169.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A157.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A151.xlsx
#
# Stimato HR-based: 12.71444267459823 km/h (4:43 min/km), val segnale: 172.8931116959596
# Letto LACT-based (Sheet3 Load @ Tlac): 14.0, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 178.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A151.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A153.xlsx
#
# Stimato HR-based: 14.291613838771184 km/h (4:12 min/km), val segnale: 175.79873976943114
# Letto LACT-based (Sheet3 Load @ Tlac): 15.9, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A153.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A152.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 15.4, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 190.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A154.xlsx
#
# Stimato HR-based: 13.888009390702491 km/h (4:19 min/km), val segnale: 173.26358956690285
# Letto LACT-based (Sheet3 Load @ Tlac): 159.0, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A154.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A149.xlsx
#
# Stimato HR-based: 15.682840934545798 km/h (3:50 min/km), val segnale: 169.66510996846984
# Letto LACT-based (Sheet3 Load @ Tlac): 16.5, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 175.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A149.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A147.xlsx
# [WARN] Dati troppo pochi in C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A147.xlsx. sp:11, hr:11, lact:0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A148.xlsx
#
# Stimato HR-based: 14.84797011158506 km/h (4:02 min/km), val segnale: 167.40852053406599
# Letto LACT-based (Sheet3 Load @ Tlac): 15.4, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 168.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A148.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A146.xlsx
# [WARN] Dati troppo pochi in C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A146.xlsx. sp:9, hr:9, lact:0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A150.xlsx
#
# Stimato HR-based: 11.758628915087524 km/h (5:06 min/km), val segnale: 183.75399347841625
# Letto LACT-based (Sheet3 Load @ Tlac): 13.0, Bla@Tlac (sheet3): 3.2, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A150.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A142.xlsx
#
# Stimato HR-based: 15.381141395404933 km/h (3:54 min/km), val segnale: 179.74043774757126
# Letto LACT-based (Sheet3 Load @ Tlac): 15.1, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 177.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A142.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A143.xlsx
#
# Stimato HR-based: 14.195470756169554 km/h (4:14 min/km), val segnale: 169.69418519664654
# Letto LACT-based (Sheet3 Load @ Tlac): 14.9, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 175.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A143.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A144.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 1.9, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A145.xlsx
#
# Stimato HR-based: 13.353496022470999 km/h (4:30 min/km), val segnale: 158.81356189534156
# Letto LACT-based (Sheet3 Load @ Tlac): 15.5, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 171.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A145.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A140.xlsx
#
# Stimato HR-based: 15.471963901260796 km/h (3:53 min/km), val segnale: 160.92685610005293
# Letto LACT-based (Sheet3 Load @ Tlac): 16.4, Bla@Tlac (sheet3): 1.6, HR@Tlac (sheet3): 165.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A140.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A137.xlsx
#
# Stimato HR-based: 16.225012474486057 km/h (3:42 min/km), val segnale: 186.0520455642969
# Letto LACT-based (Sheet3 Load @ Tlac): 18.0, Bla@Tlac (sheet3): 2.5, HR@Tlac (sheet3): 194.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A137.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A138.xlsx
#
# Stimato HR-based: 13.790077085965544 km/h (4:21 min/km), val segnale: 156.07559141292495
# Letto LACT-based (Sheet3 Load @ Tlac): 15.2, Bla@Tlac (sheet3): 1.2, HR@Tlac (sheet3): 164.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A138.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A139.xlsx
#
# Stimato HR-based: 15.468229027826803 km/h (3:53 min/km), val segnale: 155.98339955770192
# Letto LACT-based (Sheet3 Load @ Tlac): 17.2, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 164.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A139.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A141.xlsx
#
# Stimato HR-based: 14.260451405612338 km/h (4:12 min/km), val segnale: 158.00135139704525
# Letto LACT-based (Sheet3 Load @ Tlac): 15.9, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 168.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A141.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A134.xlsx
#
# Stimato HR-based: 17.26332373267889 km/h (3:29 min/km), val segnale: 170.82484314645149
# Letto LACT-based (Sheet3 Load @ Tlac): 18.4, Bla@Tlac (sheet3): 3.2, HR@Tlac (sheet3): 177.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A134.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A133.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 20.85, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 183.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A135.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.9, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 179.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A131.xlsx
#
# Stimato HR-based: 20.067782350653 km/h (2:59 min/km), val segnale: 176.51360995506224
# Letto LACT-based (Sheet3 Load @ Tlac): 19.95, Bla@Tlac (sheet3): 1.9, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A131.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A129.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 21.9, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 186.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A128.xlsx
#
# Stimato HR-based: 21.026155236044566 km/h (2:51 min/km), val segnale: 173.69842899167338
# Letto LACT-based (Sheet3 Load @ Tlac): 20.7, Bla@Tlac (sheet3): 2.1, HR@Tlac (sheet3): 171.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A128.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A130.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 20.6, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 170.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A136.xlsx
#
# Stimato HR-based: 16.43269846124235 km/h (3:39 min/km), val segnale: 179.09318610379225
# Letto LACT-based (Sheet3 Load @ Tlac): 17.0, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A136.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A132.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 20.6, Bla@Tlac (sheet3): 3.2, HR@Tlac (sheet3): 178.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A126.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.8, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 188.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A127.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.2, Bla@Tlac (sheet3): 1.6, HR@Tlac (sheet3): 171.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A125.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.7, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 166.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A124.xlsx
#
# Stimato HR-based: 17.27693198961532 km/h (3:28 min/km), val segnale: 174.17944920856843
# Letto LACT-based (Sheet3 Load @ Tlac): 19.2, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A124.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A23.xlsx
#
# Stimato HR-based: 17.307309329132174 km/h (3:28 min/km), val segnale: 173.63121952032958
# Letto LACT-based (Sheet3 Load @ Tlac): 18.6, Bla@Tlac (sheet3): 3.6, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A23.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A22.xlsx
#
# ...
#
# Stimato HR-based: 17.051438701986648 km/h (3:31 min/km), val segnale: 170.13643601061094
# Letto LACT-based (Sheet3 Load @ Tlac): 19.0, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 178.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A55.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A98.xlsx
#
# Stimato HR-based: 16.83723193056657 km/h (3:34 min/km), val segnale: 169.7240041796266
# Letto LACT-based (Sheet3 Load @ Tlac): 18.9, Bla@Tlac (sheet3): 3.6, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A98.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A92.xlsx
#
# Stimato HR-based: 13.462201368970762 km/h (4:27 min/km), val segnale: 176.75599898358308
# Letto LACT-based (Sheet3 Load @ Tlac): 14.9, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A92.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A91.xlsx
#
# Stimato HR-based: 14.30053486713543 km/h (4:12 min/km), val segnale: 177.50977652612602
# Letto LACT-based (Sheet3 Load @ Tlac): 15.6, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A91.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A90.xlsx
#
# Stimato HR-based: 15.033066225881875 km/h (3:59 min/km), val segnale: 174.3346503051223
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A90.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A87.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.4, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 166.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A88.xlsx
#
# Stimato HR-based: 15.458352844317178 km/h (3:53 min/km), val segnale: 167.1940806805244
# Letto LACT-based (Sheet3 Load @ Tlac): 17.0, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 176.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A88.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A86.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 16.1, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 174.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A94.xlsx
#
# Stimato HR-based: 12.318465647922272 km/h (4:52 min/km), val segnale: 177.60612348325327
# Letto LACT-based (Sheet3 Load @ Tlac): 13.0, Bla@Tlac (sheet3): 2.1, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A94.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A93.xlsx
#
# Stimato HR-based: 19.1667077253339 km/h (3:08 min/km), val segnale: 177.1884957638828
# Letto LACT-based (Sheet3 Load @ Tlac): 20.5, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A93.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A89.xlsx
#
# Stimato HR-based: 15.053766345361058 km/h (3:59 min/km), val segnale: 155.4143596524225
# Letto LACT-based (Sheet3 Load @ Tlac): 15.2, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 156.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A89.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A84.xlsx
#
# Stimato HR-based: 15.605858825056725 km/h (3:51 min/km), val segnale: 169.4784923327197
# Letto LACT-based (Sheet3 Load @ Tlac): 17.3, Bla@Tlac (sheet3): 3.3, HR@Tlac (sheet3): 180.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A84.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A82.xlsx
#
# Stimato HR-based: 12.292999352105376 km/h (4:53 min/km), val segnale: 158.58968878991186
# Letto LACT-based (Sheet3 Load @ Tlac): 16.5, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 181.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A82.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A83.xlsx
#
# Stimato HR-based: 13.498156222462757 km/h (4:27 min/km), val segnale: 177.70967619678453
# Letto LACT-based (Sheet3 Load @ Tlac): 15.45, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 190.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A83.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A81.xlsx
#
# Stimato HR-based: 14.869854392836592 km/h (4:02 min/km), val segnale: 175.71375324027522
# Letto LACT-based (Sheet3 Load @ Tlac): 17.0, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 187.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A81.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A85.xlsx
#
# Stimato HR-based: 15.61768489372916 km/h (3:51 min/km), val segnale: 170.02652951468772
# Letto LACT-based (Sheet3 Load @ Tlac): 17.0, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 17.7
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A85.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A79.xlsx
#
# Stimato HR-based: 13.160231146460271 km/h (4:34 min/km), val segnale: 178.22292117120855
# Letto LACT-based (Sheet3 Load @ Tlac): 14.2, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A79.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A78.xlsx
#
# Stimato HR-based: 13.6800996670629 km/h (4:23 min/km), val segnale: 178.99836876513598
# Letto LACT-based (Sheet3 Load @ Tlac): 14.7, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 183.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A78.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A77.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 18.6, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 162.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A80.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 15.8, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 176.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A75.xlsx
#
# Stimato HR-based: 16.875261593699825 km/h (3:33 min/km), val segnale: 183.4221649480814
# Letto LACT-based (Sheet3 Load @ Tlac): 18.3, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 194.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A75.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A73.xlsx
#
# Stimato HR-based: 12.588845798674827 km/h (4:46 min/km), val segnale: 187.5835882308268
# Letto LACT-based (Sheet3 Load @ Tlac): 14.0, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 193.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A73.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A72.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 14.5, Bla@Tlac (sheet3): 2.0, HR@Tlac (sheet3): 185.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A74.xlsx
#
# Stimato HR-based: 14.065192476708798 km/h (4:16 min/km), val segnale: 154.1621481336449
# Letto LACT-based (Sheet3 Load @ Tlac): 16.3, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 167.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A74.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A76.xlsx
#
# Stimato HR-based: 13.022041786488128 km/h (4:36 min/km), val segnale: 178.95673329121442
# Letto LACT-based (Sheet3 Load @ Tlac): 14.0, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 186.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A76.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A69.xlsx
#
# Stimato HR-based: 13.283344532366167 km/h (4:31 min/km), val segnale: 161.38346726270865
# Letto LACT-based (Sheet3 Load @ Tlac): 14.7, Bla@Tlac (sheet3): 3.4, HR@Tlac (sheet3): 168.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A69.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A68.xlsx
#
# Stimato HR-based: 16.301041706524824 km/h (3:41 min/km), val segnale: 176.9950264167009
# Letto LACT-based (Sheet3 Load @ Tlac): 18.0, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 189.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A68.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A70.xlsx
#
# Stimato HR-based: 13.170677056937771 km/h (4:33 min/km), val segnale: 172.53384219801504
# Letto LACT-based (Sheet3 Load @ Tlac): 13.9, Bla@Tlac (sheet3): 2.8, HR@Tlac (sheet3): 176.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A70.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A71.xlsx
#
# Stimato HR-based: 12.541203423980853 km/h (4:47 min/km), val segnale: 190.3332849644139
# Letto LACT-based (Sheet3 Load @ Tlac): 14.3, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 198.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A71.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A67.xlsx
#
# Stimato HR-based: 12.822695595746273 km/h (4:41 min/km), val segnale: 177.29398071731512
# Letto LACT-based (Sheet3 Load @ Tlac): 13.5, Bla@Tlac (sheet3): 2.4, HR@Tlac (sheet3): 181.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A67.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A655.xlsx
#
# Stimato HR-based: 12.644868917702006 km/h (4:45 min/km), val segnale: 161.26476317840024
# Letto LACT-based (Sheet3 Load @ Tlac): 13.1, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 164.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A655.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A654.xlsx
#
# Stimato HR-based: 12.227154503429965 km/h (4:54 min/km), val segnale: 176.32445027265248
# Letto LACT-based (Sheet3 Load @ Tlac): 13.2, Bla@Tlac (sheet3): 1.9, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A654.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A656.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 12.3, Bla@Tlac (sheet3): 1.8, HR@Tlac (sheet3): 163.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A651.xlsx
#
# Stimato HR-based: 12.865736870257102 km/h (4:40 min/km), val segnale: 176.9637063113013
# Letto LACT-based (Sheet3 Load @ Tlac): 14.0, Bla@Tlac (sheet3): 3.1, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A651.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A650.xlsx
#
# Stimato HR-based: 14.356212090346812 km/h (4:11 min/km), val segnale: 162.03815331579125
# Letto LACT-based (Sheet3 Load @ Tlac): 15.7, Bla@Tlac (sheet3): 1.7, HR@Tlac (sheet3): 168.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A650.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A65.xlsx
#
# Stimato HR-based: 16.44253421104056 km/h (3:39 min/km), val segnale: 161.11824410239723
# Letto LACT-based (Sheet3 Load @ Tlac): 19.3, Bla@Tlac (sheet3): 2.6, HR@Tlac (sheet3): 174.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A65.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A66.xlsx
#
# Stimato HR-based: None km/h (N/A), val segnale: None
# Letto LACT-based (Sheet3 Load @ Tlac): 19.0, Bla@Tlac (sheet3): 3.6, HR@Tlac (sheet3): 178.0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A653.xlsx
#
# Stimato HR-based: 12.077075501586425 km/h (4:58 min/km), val segnale: 173.45118012734636
# Letto LACT-based (Sheet3 Load @ Tlac): 12.5, Bla@Tlac (sheet3): 2.3, HR@Tlac (sheet3): 175.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A653.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A652.xlsx
# [WARN] Dati troppo pochi in C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A652.xlsx. sp:11, hr:11, lact:0
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A64.xlsx
#
# Stimato HR-based: 16.790607671374254 km/h (3:34 min/km), val segnale: 161.29128396172703
# Letto LACT-based (Sheet3 Load @ Tlac): 19.5, Bla@Tlac (sheet3): 2.7, HR@Tlac (sheet3): 170.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A64.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A63.xlsx
#
# Stimato HR-based: 17.536834402009365 km/h (3:25 min/km), val segnale: 172.6429917089216
# Letto LACT-based (Sheet3 Load @ Tlac): 18.4, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 179.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A63.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A62.xlsx
#
# Stimato HR-based: 18.03546676416218 km/h (3:20 min/km), val segnale: 179.11631031363274
# Letto LACT-based (Sheet3 Load @ Tlac): 18.3, Bla@Tlac (sheet3): 3.6, HR@Tlac (sheet3): 181.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A62.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A96.xlsx
#
# Stimato HR-based: 16.69085588960687 km/h (3:36 min/km), val segnale: 170.83718164532962
# Letto LACT-based (Sheet3 Load @ Tlac): 18.8, Bla@Tlac (sheet3): 2.2, HR@Tlac (sheet3): 181.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A96.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A95.xlsx
#
# Stimato HR-based: 16.66787303232207 km/h (3:36 min/km), val segnale: 169.56211737557857
# Letto LACT-based (Sheet3 Load @ Tlac): 19.2, Bla@Tlac (sheet3): 3.5, HR@Tlac (sheet3): 182.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A95.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A97.xlsx
#
# Stimato HR-based: 16.48010706874944 km/h (3:38 min/km), val segnale: 171.88603740853392
# Letto LACT-based (Sheet3 Load @ Tlac): 18.9, Bla@Tlac (sheet3): 3.2, HR@Tlac (sheet3): 184.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A97.png
#
# Processing C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\A99.xlsx
#
# Stimato HR-based: 17.491982698305502 km/h (3:26 min/km), val segnale: 177.96051910348422
# Letto LACT-based (Sheet3 Load @ Tlac): 19.1, Bla@Tlac (sheet3): 3.0, HR@Tlac (sheet3): 188.0
# Plot salvato: C:\Users\Dario\OneDrive\Desktop\PROGETTI\Test Conconi\data_v2\data\plots\soglie_A99.png

# %%
print("\n== Metriche aggregate ==")
table = [(k, v) for k, v in metrics.items()]
print(tabulate(table, headers=["Metrica", "Valore"], tablefmt="fancy_grid", floatfmt=".3f"))
# Out:
# == Metriche aggregate ==
# ╒══════════════════════════════════════╤══════════╕
# │ Metrica                              │   Valore │
# ╞══════════════════════════════════════╪══════════╡
# │ N_tests                              │  191.000 │
# ├──────────────────────────────────────┼──────────┤
# │ MAE_speed_between_methods_kmh        │    2.080 │
# ├──────────────────────────────────────┼──────────┤
# │ MDAE_speed_between_methods_kmh       │    1.299 │
# ├──────────────────────────────────────┼──────────┤
# │ ME_speed_between_methods_kmh         │   -2.040 │
# ├──────────────────────────────────────┼──────────┤
# │ MDE_speed_between_methods_kmh        │   -1.299 │
# ├──────────────────────────────────────┼──────────┤
# │ MAE_hr_between_methods_bpm           │   11.599 │
# ├──────────────────────────────────────┼──────────┤
# │ MDAE_hr_between_methods_bpm          │    6.811 │
# ├──────────────────────────────────────┼──────────┤
# │ ME_hr_between_methods_bpm            │  -11.258 │
# ├──────────────────────────────────────┼──────────┤
# │ MDE_hr_between_methods_bpm           │   -6.649 │
# ├──────────────────────────────────────┼──────────┤
# │ MAE_pace_between_methods_sec_per_km  │   20.347 │
# ├──────────────────────────────────────┼──────────┤
# │ MDAE_pace_between_methods_sec_per_km │   18.743 │
# ├──────────────────────────────────────┼──────────┤
# │ ME_pace_between_methods_sec_per_km   │   19.880 │
# ├──────────────────────────────────────┼──────────┤
# │ MDE_pace_between_methods_sec_per_km  │   18.743 │
# ╘══════════════════════════════════════╧══════════╛
